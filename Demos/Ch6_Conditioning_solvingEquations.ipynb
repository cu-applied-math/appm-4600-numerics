# %% [markdown]
# <a href="https://colab.research.google.com/github/cu-applied-math/appm-4600-numerics/blob/Fall2025/Demos/Ch6_Conditioning_solvingEquations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Condition number of a matrix
# and how it relates to the accuracy of solving a linear system

# %%
import numpy as np

# %%
n = 100

U = np.linalg.qr(np.random.randn(n, n))[0]
V = np.linalg.qr(np.random.randn(n, n))[0]

# %%
s = np.logspace(-8, 0, n)
A = U @ np.diag(s) @ V.T

s = np.logspace(-2, 0, n)
B = U @ np.diag(s) @ V.T

print(f'Condition number of A is {np.linalg.cond(A):.2e}')
print(f'Condition number of B is {np.linalg.cond(B):.2e}')
# Out:
# Condition number of A is 1.00e+08
# Condition number of B is 1.00e+02

# %%
x = np.ones(n)

xhat = np.linalg.solve(A, A@x)
print(f'Error solving A is {np.linalg.norm(xhat - x):.2e}')

xhat = np.linalg.solve(B, B@x)
print(f'Error solving B is {np.linalg.norm(xhat - x):.2e}')
# Out:
# Error solving A is 1.29e-08
# Error solving B is 4.84e-14
